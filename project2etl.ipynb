# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "Raw Data/CO2 Emission Per Cap.csv"
carbone_df = pd.read_csv(csv_file, skiprows=3)
carbone_df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                            Indicator Name  Indicator Code  1960  1961  1962  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   NaN   NaN   NaN
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   NaN   NaN   NaN
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   NaN   NaN   NaN
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   NaN   NaN   NaN
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   NaN   NaN   NaN
#
#    1963  1964  1965  ...      2013      2014      2015      2016      2017  \
# 0   NaN   NaN   NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1   NaN   NaN   NaN  ...  1.005027  1.016649  0.966589  0.948410  0.937926
# ...

# %%
new_carbone_df = carbone_df.loc[:, '1990':'2021']

new_carbone_df.head()
# Out:
#        1990      1991      1992      1993      1994      1995      1996  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  0.999038  0.953224  0.915661  0.916485  0.917093  0.936570  0.947393
# 2  0.191745  0.167682  0.095958  0.084721  0.075546  0.068468  0.062588
# 3  0.478144  0.530016  0.568305  0.523529  0.470888  0.501681  0.564390
# 4  0.553662  0.544539  0.543557  0.708984  0.836804  0.912141  1.072168
#
#        1997      1998      1999  ...      2012      2013      2014      2015  \
# 0       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 1  0.967836  0.967182  0.904871  ...  0.992616  1.005027  1.016649  0.966589
# 2  0.056827  0.052691  0.040157  ...  0.259295  0.185624  0.146236  0.172897
# 3  0.549638  0.514868  0.511254  ...  0.480603  0.508099  0.515960  0.494065
# 4  1.086637  1.091825  1.109860  ...  0.950696  1.036294  1.099779  1.135044
#
#        2016      2017      2018      2019  2020  2021
# ...

# %%
csv_file = "Raw Data/GDP Per Cap.csv"
gdp_df = pd.read_csv(csv_file, skiprows=3)
gdp_df.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                  Afghanistan          AFG  GDP per capita (current US$)
# 3   Africa Western and Central          AFW  GDP per capita (current US$)
# 4                       Angola          AGO  GDP per capita (current US$)
#
#    Indicator Code        1960        1961        1962        1963        1964  \
# 0  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
# 1  NY.GDP.PCAP.CD  162.726325  162.555968  172.271022  199.784916  180.228774
# 2  NY.GDP.PCAP.CD   59.773234   59.860900   58.458009   78.706429   82.095307
# 3  NY.GDP.PCAP.CD  107.930722  113.080062  118.829461  123.441089  131.852423
# 4  NY.GDP.PCAP.CD         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
new_gdp_df = gdp_df.loc[:, '1990':'2021']

new_gdp_df.head()
# Out:
#            1990          1991          1992          1993          1994  \
# 0  12305.387908  13494.685160  14048.347273  14942.274963  16241.575593
# 1    831.202019    872.391306    739.303650    714.009949    705.447265
# 2           NaN           NaN           NaN           NaN           NaN
# 3    594.725717    558.435766    547.662947    445.656045    378.940377
# 4    947.704262    865.692730    656.362015    441.200842    328.673149
#
#            1995          1996          1997          1998          1999  ...  \
# 0  16441.790636  16583.003066  17926.782626  19080.695789  19356.526058  ...
# 1    771.259980    747.767103    765.890061    703.028889    675.739876  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3    462.864798    523.763417    515.234541    513.642464    528.580607  ...
# 4    397.179479    522.643698    514.295154    423.593688    387.784267  ...
#
# ...

# %% [markdown]
# ### Create new data with select columns

# %%
new_carbone1_df =carbone_df.iloc[:,0:2]
new_carbone1_df.head()
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO

# %%
result = [new_carbone1_df, new_carbone_df]
result1 = pd.concat(result, axis=1)
display(result1)
# Out:
#                     Country Name Country Code      1990      1991      1992  \
# 0                          Aruba          ABW       NaN       NaN       NaN
# 1    Africa Eastern and Southern          AFE  0.999038  0.953224  0.915661
# 2                    Afghanistan          AFG  0.191745  0.167682  0.095958
# 3     Africa Western and Central          AFW  0.478144  0.530016  0.568305
# 4                         Angola          AGO  0.553662  0.544539  0.543557
# ..                           ...          ...       ...       ...       ...
# 261                       Kosovo          XKX       NaN       NaN       NaN
# 262                  Yemen, Rep.          YEM  0.567037  0.690937  0.704793
# 263                 South Africa          ZAF  6.729799  6.424622  6.175430
# 264                       Zambia          ZMB  0.340930  0.349232  0.337224
# 265                     Zimbabwe          ZWE  1.585444  1.713321  1.694416
#
# ...

# %%
new_gdp1_df = gdp_df.iloc[:,0:2]
new_gdp1_df.head()
# Out:
#                   Country Name Country Code
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO

# %%
result = [new_gdp1_df, new_gdp_df]
result1 = pd.concat(result, axis=1)
display(result1)
# Out:
#                     Country Name Country Code          1990          1991  \
# 0                          Aruba          ABW  12305.387908  13494.685160
# 1    Africa Eastern and Southern          AFE    831.202019    872.391306
# 2                    Afghanistan          AFG           NaN           NaN
# 3     Africa Western and Central          AFW    594.725717    558.435766
# 4                         Angola          AGO    947.704262    865.692730
# ..                           ...          ...           ...           ...
# 261                       Kosovo          XKX           NaN           NaN
# 262                  Yemen, Rep.          YEM    482.248121    482.060571
# 263                 South Africa          ZAF   3425.174231   3584.522515
# 264                       Zambia          ZMB    408.769331    409.727275
# 265                     Zimbabwe          ZWE    841.973958    809.051140
#
#              1992          1993          1994          1995          1996  \
# ...

# %% [markdown]
# ### Store JSON data into a DataFrame

# %%
json_file = "../Resources/customer_location.json"
customer_location_df = pd.read_json(json_file)
customer_location_df.head()

# %% [markdown]
# ### Clean DataFrame

# %%
new_customer_location_df = customer_location_df[["id", "address", "city", "aus_state"]].copy()
new_customer_location_df.head()

# %% [markdown]
# ### Connect to local database

# %%
protocol = 'postgresql'
username = '<user name>'
password = '<password>'
host = 'localhost'
port = 5432
database_name = 'customer_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
insp = inspect(engine)

# %% [markdown]
# ### Check for tables

# %%
insp.get_table_names()

# %% [markdown]
# ### Use pandas to load csv converted DataFrame into database

# %%
new_customer_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Use pandas to load json converted DataFrame into database

# %%
new_customer_location_df.to_sql(name='customer_location', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the customer_name table
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from customer_name', con=engine).head()

# %% [markdown]
# ### Confirm data has been added by querying the customer_location table

# %%
pd.read_sql_query('select * from customer_location', con=engine).head()

# %%
sql_join = r"""SELECT customer_name.id, customer_name.first_name, customer_name.last_name, 
customer_location.address, customer_location.city, customer_location.aus_state
FROM customer_name
JOIN customer_location
ON customer_name.id = customer_location.id"""
pd.read_sql_query(sql_join, con=engine).head()
